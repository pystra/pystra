# %% [markdown]
# # Design-point calibration of safety and combination factors
#
# This specialist workflow solves cases to a target reliability and derives $\phi$, $\gamma$, and $\psi$ from their design points. The normalized candidate-factor workflow is demonstrated separately in [Generic code calibration](ex_generic_calibration.ipynb).

# %% [markdown]
# ## Reference problem
#
# The numerical inputs below preserve the existing Sørensen Example 4 / Caprani and Khan reference example. Maximum and companion distributions are supplied explicitly; no reference-period conversion is inferred. The coefficient method compares design-point/nominal ratios. The matrix method follows the column-wise leading-action effect convention used by Caprani and Khan (Structural Safety, 2023; see also ICASP14, *Determination of load combination factors for the assessment of existing bridges*).
#
# Both methods assume a separable resistance-scale design rule, including multiplicative model errors. They are not a decomposition of an arbitrary nonlinear limit state.

# %%
import pystra as ra
import numpy as np

def limit_state(z, R, G, Q1, Q2, cg):
    return z*R - (cg*G + 0.6*Q1 + 0.3*Q2)

maxima = {"Q1":ra.Gumbel("Q1",1,0.2), "Q2":ra.Gumbel("Q2",1,0.4)}
companions = {"Q1":ra.Gumbel("Q1",0.89,0.2), "Q2":ra.Gumbel("Q2",0.77,0.4)}
resistance = ra.Lognormal("R",1,0.15)
permanent = ra.Normal("G",1,0.1)
cases = ra.LoadCombination.from_actions(
    maxima=maxima, companions=companions, resistance=[resistance], other=[permanent],
    constants=[ra.Constant("z",1), ra.Constant("cg",0.4)], limit_state=limit_state,
)
nominal_values = {"R":resistance.ppf(0.05), "G":permanent.ppf(0.5),
                  "Q1":maxima["Q1"].ppf(0.98), "Q2":maxima["Q2"].ppf(0.98)}
problem = ra.FactorCalibrationProblem(cases, nominal_values=nominal_values, design_parameter="z")
target_beta = 4.3

# %% [markdown]
# ## Solve designs to the target
#
# `root` records the outer root-solver diagnostics and checks inner FORM convergence and the final target residual. Supply `bracket=(lower, upper)` to use a bracketed solve. The separate `alpha` method projects in independent normal space. Failed solves remain in `solutions.designs`; factor derivation refuses them.

# %%
solutions = ra.solve_designs(problem, target_beta=target_beta, method="root")
assert solutions.converged
solutions.to_frame()
# Out:
#                R         G        Q1        Q2         z
# Q1_max  0.655286  1.037132  1.623560  2.017120  3.043135
# Q2_max  0.655030  1.037126  1.512911  2.245823  3.047713

# %% [markdown]
# ## Derive factors
#
# Factor sets store immutable numerical rows with named case and variable axes. Reporting tables are independent copies. Each variable action must have exactly one leading case; the method rejects unsupported case topologies.

# %%
factors = ra.derive_factors(solutions, method="coeff")
for kind in ("resistance", "loads", "combinations"):
    display(factors.to_frame(kind))
# Out:
#                R
# Q1_max  0.846876
# Q2_max  0.846545
#                G        Q1        Q2
# Q1_max  1.037132  1.069218  1.102563
# Q2_max  1.037126  1.069218  1.102563
#           G        Q1        Q2
# Q1_max  1.0  1.000000  0.898165
# Q2_max  1.0  0.931848  1.000000

# %% [markdown]
# ## Select factors, design, and verify
#
# Selection is explicit. Leading-action combination factors remain one; companion maxima are selected by name. Governing-case provenance is retained. The largest required resistance scale is explicitly chosen for the common design and rechecked across all cases.

# %%
selected = ra.select_factors(factors, resistance="minimum", loads="maximum", combinations="maximum")
designs = ra.design_with_factors(problem, selected)
checks = ra.verify_designs(problem, max(designs.values), target_beta=target_beta)
for check in checks:
    print(check.case_name, check.design_value, check.reliability.beta, check.target_margin)
assert all(check.reliability.converged for check in checks)
selected.governing
# Out:
# Q1_max 3.047717273919197 4.306471480120912 0.006471480120912254
# Q2_max 3.047717273919197 4.300005603159019 5.603159019429427e-06
# (GoverningFactor(kind='resistance', variable='R', case_names=('Q2_max',)),
#  GoverningFactor(kind='loads', variable='G', case_names=('Q1_max',)),
#  GoverningFactor(kind='loads', variable='Q1', case_names=('Q1_max', 'Q2_max')),
#  GoverningFactor(kind='loads', variable='Q2', case_names=('Q1_max', 'Q2_max')),
#  GoverningFactor(kind='combinations', variable='G', case_names=('Q1_max', 'Q2_max')),
#  GoverningFactor(kind='combinations', variable='Q1', case_names=('Q2_max',)),
#  GoverningFactor(kind='combinations', variable='Q2', case_names=('Q1_max',)))

# %% [markdown]
# ## Compare the supported method combinations

# %%
for design_method, factor_method in [("root","coeff"), ("root","matrix"), ("alpha","matrix")]:
    solved = ra.solve_designs(problem, target_beta=target_beta, method=design_method)
    assert solved.converged
    estimated = ra.derive_factors(solved, method=factor_method)
    selected = ra.select_factors(estimated, resistance="minimum", loads="maximum", combinations="maximum")
    design = ra.design_with_factors(problem, selected)
    verified = ra.verify_designs(problem, max(design.values), target_beta=target_beta)
    print(design_method, factor_method, [c.reliability.beta for c in verified])
# Out:
# root coeff [4.306471480120912, 4.300005603159019]
# root matrix [4.306471113319907, 4.300005235952576]
# alpha matrix [4.306460647675186, 4.299994758739553]

# %% [markdown]
# ## Multiplicative resistance and load model errors
#
# The following reference example includes nonlinear products. Roles explicitly associate each model error with its side of the limit state. The matrix method evaluates each action coefficient in its own leading case, preserving the original formulation.

# %%
def nonlinear_limit_state(scale, wR, R, wS, Q1, Q2):
    return scale*wR*R - wS*(Q1+Q2)

resistance = ra.Normal("R",60,6)
maxima = {"Q1":ra.Normal("Q1",30,3), "Q2":ra.Normal("Q2",20,2)}
companions = {"Q1":ra.Normal("Q1",15,3), "Q2":ra.Normal("Q2",10,2)}
cases = ra.LoadCombination.from_actions(
    maxima=maxima, companions=companions,
    resistance=[resistance,ra.Lognormal("wR",1,0.05)],
    other=[ra.Lognormal("wS",1,0.1)],
    constants=[ra.Constant("scale",1)], limit_state=nonlinear_limit_state,
)
problem = ra.FactorCalibrationProblem(cases, design_parameter="scale", nominal_values={
    "wR":1, "wS":1, "R":resistance.ppf(0.05),
    "Q1":maxima["Q1"].ppf(0.95), "Q2":maxima["Q2"].ppf(0.95),
})
solutions = ra.solve_designs(problem,target_beta=3.7)
assert solutions.converged
factors = ra.derive_factors(solutions,method="matrix")
selected = ra.select_factors(factors,loads="maximum")
designs = ra.design_with_factors(problem,selected)
checks = ra.verify_designs(problem,max(designs.values),target_beta=3.7)
for check in checks:
    print(check.case_name,check.reliability.beta,check.target_margin)
# Out:
# Q1_max 3.7039102295177426 0.003910229517742447
# Q2_max 4.28712854669924 0.5871285466992395
