# %% [markdown]
# # Quick Demonstration for Global calibration of safety and combination factors
#
# Calibrate a set of safety and combination factors for two different structures identified by two different LSFs.
#
# The first LSF is given by:
# $$ z_1*R \geq (0.4*G + 0.6*Q1 + 0.3*Q2)$$
#
# The second LSF is given by:
# $$ z_2*R \geq (0.4*G + 0.3*Q1 + 0.6*Q2)$$
#
# Note:
# 1. I think it is reasonable to assume that any global calibration exercise would contain the same load effects albeit with different nominal values.
# 2. This is just a quick demonstration.
# 3. The objective is also to utilize as much as existing Pystra code as possible.
#
# ## Import Libraries and define utility functions

# %%
import pystra as ra
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# %%
def lsf(z, R, G, Q1, Q2, cg, c1, c2):
    return z*R - (cg*G + c1*Q1 + c2*Q2)

# %%
def make_load_factor_table(gg, g1, g2):
    """
    Create a Dataframe of Gamma factors from a set of input values such that
    it can be utilized by the respective calibration object.

    """
    load_factor_row = [gg, g1, g2]
    cols = ['G', 'Q1', 'Q2']
    idx = ['Q1_max', 'Q2_max']
    df = pd.DataFrame(data=[load_factor_row, load_factor_row], columns=cols, index=idx)
    return df

def make_resistance_factor_table(phi):
    """
    Create a Dataframe of Phi factors from a set of input values such that
    it can be utilized by the respective calibration object.

    """
    resistance_factor_row = [phi]
    cols = ['R']
    idx = ['Q1_max', 'Q2_max']
    df = pd.DataFrame(data=[resistance_factor_row, resistance_factor_row], columns=cols, index=idx)
    return df
    
def make_combination_factor_table(psi1, psi2):
    """
    Create a Dataframe of Psi factors from a set of input values such that
    it can be utilized by the respective calibration object.

    """
    q1_leading_factors = [1, 1, psi2]
    q2_leading_factors = [1, psi1, 1]
    cols = ['G', 'Q1', 'Q2']
    idx = ['Q1_max', 'Q2_max']
    df = pd.DataFrame(data=[q1_leading_factors, q2_leading_factors], columns=cols, index=idx)
    return df

# %%
def run_calib_design(resistance_factors, load_factors, combination_factors, calib):
    """
    Take a set of factors for a calibration object and run a design check.

    """
    calib.resistance_factors = resistance_factors
    calib.load_factors = load_factors
    calib.combination_factors = combination_factors
    design_z = calib.get_design_param_factor()
    design_beta = calib.calc_beta_design_param(np.max(design_z))
    return design_beta

# %%
def obj_func_global(factor_values):
    """
    Objective function for minimization: weighted mean sequared error.
    Taken from Gayton (2004) pg. 5.

    Takes a set of input parameters, creates corresponding dataframes,
    finds corresponding design reliabilities for each calibration object,
    and returns the residual.
    """
    gg, g1, g2, psi1, psi2, phi = factor_values
    resistance_factors = make_resistance_factor_table(phi)
    load_factors = make_load_factor_table(gg, g1, g2)
    combination_factors = make_combination_factor_table(psi1, psi2)
    design_beta1 = run_calib_design(resistance_factors, load_factors, combination_factors, calib1)
    design_beta2 = run_calib_design(resistance_factors, load_factors, combination_factors, calib2)
    case_reliabilities = np.concatenate([design_beta1, design_beta2])
    case_weights = np.ones(4)
    res = np.sum([xx * (yy-betaT)**2 for xx,yy in zip(case_weights, case_reliabilities)])
    return res

# %% [markdown]
# ## Set up problem input

# %%
## Set parameters for LoadCombination: Distributions and combinations
# Annual max distributions
Q1max = ra.Gumbel("Q1", 1, 0.2)  # Imposed Load
Q2max = ra.Gumbel("Q2", 1, 0.4)  # Wind Load
# Parameters of inferred point-in-time parents
Q1pit = ra.Gumbel("Q1", 0.89, 0.2)  # Imposed Load
Q2pit = ra.Gumbel("Q2", 0.77, 0.4)  # Wind Load
Q_dict = {'Q1': {'max': Q1max, 'pit': Q1pit},
          'Q2': {'max': Q2max, 'pit': Q2pit}}
# Constant values
cg1 = ra.Constant("cg", 0.4)
c11 = ra.Constant("c1", 0.6)
c21 = ra.Constant("c2", 0.3)
cg2 = ra.Constant("cg", 0.4)
c12 = ra.Constant("c1", 0.3)
c22 = ra.Constant("c2", 0.6)
z = ra.Constant("z", 1)  # Design parameter for resistance with arbitrary default value

## Define other random variables
Rdist = ra.Lognormal("R", 1.0, 0.15)  # Resistance
Gdist = ra.Normal("G", 1, 0.1)  # Permanent Load (other load variable)
loadcombinations = {'Q1_max':['Q1'], 'Q2_max':['Q2']}

# %%
## Set parameters for calibration: nominal values and target Beta
Qk = np.array([Q1max.ppf(0.98), Q2max.ppf(0.98)])
Gk = np.array([Gdist.ppf(0.5)])
Rk = np.array([Rdist.ppf(0.05)])
rvs_all = ['R', 'G', 'Q1', 'Q2', 'Q3']
nominal_values = dict(zip(rvs_all, np.concatenate([Rk, Gk, Qk])))
betaT = 4.3

# %% [markdown]
# ## Instantiate Combination and Calibration Objects

# %%
## Instantiate LoadCombination object
lc1 = ra.LoadCombination(
    lsf=lsf,
    action_distributions=Q_dict,
    resistance=[Rdist],
    other_variables=[Gdist],
    constants=[z, cg1, c11, c21],
    leading_actions=loadcombinations,
)
lc2 = ra.LoadCombination(
    lsf=lsf,
    action_distributions=Q_dict,
    resistance=[Rdist],
    other_variables=[Gdist],
    constants=[z, cg2, c12, c22],
    leading_actions=loadcombinations,
)


## Instantiate Calibration object
calib1 = ra.Calibration(lc1, target_beta=betaT, nominal_values=nominal_values,
                        design_parameter='z', factor_method="matrix", 
                        design_method="optimize", print_output=False)

calib2 = ra.Calibration(lc2, target_beta=betaT, nominal_values=nominal_values,
                        design_parameter='z', factor_method="matrix", 
                        design_method="optimize", print_output=False)
# Out:
# /tmp/ipykernel_1827963/1742732751.py:2: DeprecationWarning: action_distributions, resistance, other_variables, legacy_constants, and leading_actions are deprecated. Use LoadCombination(cases=...) or LoadCombination.turkstra(...) instead.
#   lc1 = ra.LoadCombination(
# /tmp/ipykernel_1827963/1742732751.py:10: DeprecationWarning: action_distributions, resistance, other_variables, legacy_constants, and leading_actions are deprecated. Use LoadCombination(cases=...) or LoadCombination.turkstra(...) instead.
#   lc2 = ra.LoadCombination(

# %% [markdown]
# ## Global Optimization

# %%
## Run Global optimization
# Starting values taken from results of calib1.run()
start = [1.0371, 1.069218, 1.102563, 0.931848, 0.898165, 0.846876]
# Specify Bounds for the respective parameters
g_low = 1.0
g_up = 1.6
psi_low = 0.1
psi_up = 1.0
phi_low = 0.5
phi_up = 1.0
bnds = ((g_low, g_up), (g_low, g_up), (g_low, g_up), (psi_low, psi_up), 
        (psi_low, psi_up), (phi_low, phi_up))
# Optimize
result = minimize(obj_func_global, x0=start, bounds=bnds)

# %% [markdown]
# ### Store results

# %%
factors_opt = result.x

opt_res = obj_func_global(factors_opt)
optimized_resistance_factors = make_resistance_factor_table(factors_opt[5])
optimized_load_factors = make_load_factor_table(factors_opt[0], factors_opt[1], factors_opt[2])
optimized_combination_factors = make_combination_factor_table(factors_opt[3], factors_opt[4])
design_beta_1_opt = run_calib_design(optimized_resistance_factors, optimized_load_factors, optimized_combination_factors, calib1)
design_beta_2_opt = run_calib_design(optimized_resistance_factors, optimized_load_factors, optimized_combination_factors, calib2)

# %% [markdown]
# ### Display results

# %%
# Display results
print(f'\n Phi optimal = \n{optimized_resistance_factors}')
print(f'\n Gamma optimal = \n{optimized_load_factors}')
print(f'\n Psi optimal = \n{optimized_combination_factors}')
print(f'\nOptimal design reliabilities for problem 1: {design_beta_1_opt}')
print(f'\nOptimal design reliabilities for problem 2: {design_beta_2_opt}')
# Out:
#  Phi optimal =
#                R
# Q1_max  0.838726
# Q2_max  0.838726
#
#  Gamma optimal =
#           G   Q1        Q2
# Q1_max  1.0  1.0  1.504568
# Q2_max  1.0  1.0  1.504568
#
#  Psi optimal =
#         G        Q1        Q2
# Q1_max  1  1.000000  0.723674
# Q2_max  1  0.717378  1.000000
#
# Optimal design reliabilities for problem 1: [4.30323644 4.29676698]
#
# Optimal design reliabilities for problem 2: [4.36206135 4.2394964 ]

# %% [markdown]
# Note that the optimal design reliabilities can be slightly less than the target reliability because there is no constraint on setting $\beta_j\geq \beta_T$

# %% [markdown]
# The objective minimizes a weighted sum of squared deviations from the target. It does not impose a minimum reliability constraint on every case. Inspect both structures and all leading-action cases: a small aggregate residual can still include individual reliabilities below the target.
