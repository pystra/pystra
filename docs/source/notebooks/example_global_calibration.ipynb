# %% [markdown]
# # Global calibration of a shared factor set
#
# This archived example fits a shared set of factors across two structures using a weighted squared-error objective. The objective and bounds are explicit choices for this example. It uses the public factor/design/verification operations without mutating reporting tables.

# %%
import pystra as ra
import numpy as np
from scipy.optimize import minimize

def limit_state(z,R,G,Q1,Q2,cg,c1,c2):
    return z*R - (cg*G+c1*Q1+c2*Q2)

maxima = {"Q1":ra.Gumbel("Q1",1,0.2),"Q2":ra.Gumbel("Q2",1,0.4)}
companions = {"Q1":ra.Gumbel("Q1",0.89,0.2),"Q2":ra.Gumbel("Q2",0.77,0.4)}
resistance=ra.Lognormal("R",1,0.15)
permanent=ra.Normal("G",1,0.1)
nominal_values={"R":resistance.ppf(0.05),"G":permanent.ppf(0.5),
                "Q1":maxima["Q1"].ppf(0.98),"Q2":maxima["Q2"].ppf(0.98)}
problems=[]
for c1,c2 in [(0.6,0.3),(0.3,0.6)]:
    cases=ra.LoadCombination.from_actions(
        maxima=maxima,companions=companions,resistance=[resistance],other=[permanent],
        constants=[ra.Constant("z",1),ra.Constant("cg",0.4),ra.Constant("c1",c1),ra.Constant("c2",c2)],
        limit_state=limit_state,
    )
    problems.append(ra.calibration.FactorCalibrationProblem(cases,nominal_values=nominal_values,design_parameter="z"))
target_beta=4.3

# %%
def make_factors(values):
    gg,g1,g2,psi1,psi2,phi=values
    return ra.calibration.FactorSet(
        case_names=("Q1_max","Q2_max"),resistance_names=("R",),load_names=("G","Q1","Q2"),
        resistance=((phi,),(phi,)),loads=((gg,g1,g2),(gg,g1,g2)),
        combinations=((1,1,psi2),(1,psi1,1)),leading_actions=(("Q1",),("Q2",)),
    )

def evaluate(problem,factors):
    design=ra.calibration.design_with_factors(problem,factors)
    checks=ra.calibration.verify_designs(problem,max(design.values),target_beta=target_beta)
    if not all(c.reliability.converged for c in checks):
        raise RuntimeError("A candidate design failed reliability analysis")
    return np.array([c.reliability.beta for c in checks])

def objective(values):
    factors=make_factors(values)
    beta=np.concatenate([evaluate(problem,factors) for problem in problems])
    return np.sum((beta-target_beta)**2)

# %%
start=[1.0371,1.069218,1.102563,0.931848,0.898165,0.846876]
bounds=((1,1.6),(1,1.6),(1,1.6),(0.1,1),(0.1,1),(0.5,1))
optimization=minimize(objective,x0=start,bounds=bounds)
print(optimization.message)
factors=make_factors(optimization.x)
for kind in ("resistance","loads","combinations"):
    display(factors.to_frame(kind))
for i,problem in enumerate(problems,1):
    print(f"Problem {i}: {evaluate(problem,factors)}")
# Out:
# CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
#                R
# Q1_max  0.838726
# Q2_max  0.838726
#           G   Q1        Q2
# Q1_max  1.0  1.0  1.504568
# Q2_max  1.0  1.0  1.504568
#           G        Q1        Q2
# Q1_max  1.0  1.000000  0.723674
# Q2_max  1.0  0.717378  1.000000
# Problem 1: [4.30323644 4.29676698]
# Problem 2: [4.36206135 4.2394964 ]

# %% [markdown]
# The objective minimizes a sum of squared target deviations. It does not require every individual case to meet the target. Inspect all four achieved reliabilities before accepting a factor set. An explicit constrained formulation would be a different engineering choice.
